# %%
import keras
from keras.applications import VGG16
from keras.models import Model
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.applications.vgg16 import VGG16
import os
import numpy as np
from keras.applications.imagenet_utils import preprocess_input 
from keras.utils import np_utils
import random
import pprint
import cPickle
from scipy.misc import imread, imresize, imsave
from keras.layers.normalization import BatchNormalization
from keras import backend as K
from keras.engine.topology import Merge, merge
import matplotlib.pyplot as plt
from PIL import Image

# %%
# %matplotlib inline

# %%
train_datagen = ImageDataGenerator(
        featurewise_center=True,
        rescale=1./255,
        dim_ordering='tf')

# %%
random.seed(0)

X_train = []
Y_train = []

for directory in os.listdir('./data/'):
    l = os.listdir('./data/' + directory)
    for image in l:
        image = l[0]
        img = load_img('./data/' + directory + '/' + image, target_size=(224,224))  # this is a PIL image
        img = img.convert("YCbCr")
        x = img_to_array(img)
        Y_train.append(x[:,:,1:])
        X_train.append(x[:,:,:1])
    break
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
XX_train = np.zeros((X_train.shape[0], X_train.shape[1], X_train.shape[2], X_train.shape[3] + 2))
XX_train[:,:,:,0:] = X_train
XX_train.shape
# Out:
# (114, 224, 224, 3)

# %%
def getModel():
    ''' 
        * return: compiled model (keras.engine.training.Model)
    '''
    vgg_model = VGG16( weights='imagenet', include_top=True )
    for i in range(9):
        vgg_model.layers.pop()    
    
    bnl = BatchNormalization() (vgg_model.layers[-1].output)
    cnl = Convolution2D(256, 1, 1, border_mode='same', dim_ordering='tf') (bnl)
    usl = UpSampling2D(dim_ordering='tf') (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-5].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(128, 3, 3, border_mode='same', dim_ordering='tf') (ml)

    usl = UpSampling2D(dim_ordering='tf') (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-9].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(64, 3, 3, border_mode='same', dim_ordering='tf') (ml)

    usl = UpSampling2D(dim_ordering='tf') (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-12].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(3, 3, 3, border_mode='same', dim_ordering='tf') (ml)

    bnl = BatchNormalization() (vgg_model.layers[-14].output)
    ml = merge([cnl, bnl], mode='sum')
    cnl = Convolution2D(3, 3, 3, border_mode='same', dim_ordering='tf') (ml)

    cnl = Convolution2D(2, 3, 3, border_mode='same', dim_ordering='tf') (cnl)

    tl_model = Model( input=vgg_model.input, output=cnl )
    for i in range(1, 14):
        tl_model.layers[i].trainable = False

    return tl_model

# %%
##loss function

# def blur_uv_loss(rgb, inferred_rgb):
#     uv = rgb2uv(rgb)
#     uv_blur0 = rgb2uv(blur(rgb, 3))
#     uv_blur1 = rgb2uv(blur(rgb, 5))

#     inferred_uv = rgb2uv(inferred_rgb)
#     inferred_uv_blur0 = rgb2uv(blur(inferred_rgb, 3))
#     inferred_uv_blur1 = rgb2uv(blur(inferred_rgb, 5))

#     return  ( dist(inferred_uv, uv) +
#             dist(inferred_uv_blur0 , uv_blur0) +
#             dist(inferred_uv_blur1, uv_blur1) ) / 3

# %%
tl_model = getModel()
# pprint.PrettyPrinter(indent=2).pprint(tl_model.get_config())
tl_model.summary()

tl_model.compile(loss="mse", optimizer="adam", metrics=["acc"])
# Out:
# ____________________________________________________________________________________________________
# Layer (type)                     Output Shape          Param #     Connected to
# ====================================================================================================
# input_3 (InputLayer)             (None, 224, 224, 3)   0
# ____________________________________________________________________________________________________
# block1_conv1 (Convolution2D)     (None, 224, 224, 64)  1792        input_3[0][0]
# ____________________________________________________________________________________________________
# block1_conv2 (Convolution2D)     (None, 224, 224, 64)  36928       block1_conv1[0][0]
# ____________________________________________________________________________________________________
# block1_pool (MaxPooling2D)       (None, 112, 112, 64)  0           block1_conv2[0][0]
# ____________________________________________________________________________________________________
# block2_conv1 (Convolution2D)     (None, 112, 112, 128) 73856       block1_pool[0][0]
# ____________________________________________________________________________________________________
# block2_conv2 (Convolution2D)     (None, 112, 112, 128) 147584      block2_conv1[0][0]
# ____________________________________________________________________________________________________
# block2_pool (MaxPooling2D)       (None, 56, 56, 128)   0           block2_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_conv1 (Convolution2D)     (None, 56, 56, 256)   295168      block2_pool[0][0]
# ____________________________________________________________________________________________________
# block3_conv2 (Convolution2D)     (None, 56, 56, 256)   590080      block3_conv1[0][0]
# ____________________________________________________________________________________________________
# block3_conv3 (Convolution2D)     (None, 56, 56, 256)   590080      block3_conv2[0][0]
# ____________________________________________________________________________________________________
# block3_pool (MaxPooling2D)       (None, 28, 28, 256)   0           block3_conv3[0][0]
# ____________________________________________________________________________________________________
# block4_conv1 (Convolution2D)     (None, 28, 28, 512)   1180160     block3_pool[0][0]
# ____________________________________________________________________________________________________
# block4_conv2 (Convolution2D)     (None, 28, 28, 512)   2359808     block4_conv1[0][0]
# ____________________________________________________________________________________________________
# block4_conv3 (Convolution2D)     (None, 28, 28, 512)   2359808     block4_conv2[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_11 (BatchNorm (None, 28, 28, 512)   2048        block4_conv3[0][0]
# ____________________________________________________________________________________________________
# convolution2d_13 (Convolution2D) (None, 28, 28, 256)   131328      batchnormalization_11[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_7 (UpSampling2D)    (None, 56, 56, 256)   0           convolution2d_13[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_12 (BatchNorm (None, 56, 56, 256)   1024        block3_conv3[0][0]
# ____________________________________________________________________________________________________
# merge_9 (Merge)                  (None, 56, 56, 256)   0           upsampling2d_7[0][0]
#                                                                    batchnormalization_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_14 (Convolution2D) (None, 56, 56, 128)   295040      merge_9[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_8 (UpSampling2D)    (None, 112, 112, 128) 0           convolution2d_14[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_13 (BatchNorm (None, 112, 112, 128) 512         block2_conv2[0][0]
# ____________________________________________________________________________________________________
# merge_10 (Merge)                 (None, 112, 112, 128) 0           upsampling2d_8[0][0]
#                                                                    batchnormalization_13[0][0]
# ____________________________________________________________________________________________________
# convolution2d_15 (Convolution2D) (None, 112, 112, 64)  73792       merge_10[0][0]
# ____________________________________________________________________________________________________
# upsampling2d_9 (UpSampling2D)    (None, 224, 224, 64)  0           convolution2d_15[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_14 (BatchNorm (None, 224, 224, 64)  256         block1_conv2[0][0]
# ____________________________________________________________________________________________________
# merge_11 (Merge)                 (None, 224, 224, 64)  0           upsampling2d_9[0][0]
#                                                                    batchnormalization_14[0][0]
# ____________________________________________________________________________________________________
# convolution2d_16 (Convolution2D) (None, 224, 224, 3)   1731        merge_11[0][0]
# ____________________________________________________________________________________________________
# batchnormalization_15 (BatchNorm (None, 224, 224, 3)   12          input_3[0][0]
# ____________________________________________________________________________________________________
# merge_12 (Merge)                 (None, 224, 224, 3)   0           convolution2d_16[0][0]
#                                                                    batchnormalization_15[0][0]
# ____________________________________________________________________________________________________
# convolution2d_17 (Convolution2D) (None, 224, 224, 3)   84          merge_12[0][0]
# ____________________________________________________________________________________________________
# convolution2d_18 (Convolution2D) (None, 224, 224, 2)   56          convolution2d_17[0][0]
# ====================================================================================================
# Total params: 8,141,147
# Trainable params: 503,957
# Non-trainable params: 7,637,190
# ____________________________________________________________________________________________________

# %%
train_datagen.fit(X_train)

# %%
# history = tl_model.fit_generator(train_datagen.flow(X_train,Y_train,batch_size=88), samples_per_epoch=88, nb_epoch=50, validation_data=(X_valid,Y_valid), verbose=1)

history = tl_model.fit(XX_train[:10,:,:,:],Y_train[:10,:,:,:],batch_size=5, nb_epoch=100, verbose=1, shuffle=True)

# tl_model.save(filepath='./output/urban_2_images')
# cPickle.dump( history.history, open( "urbnan_2_images.p", "wb" ) )
# Out:
# Epoch 1/100
# 10/10 [==============================] - 25s - loss: 66.9945 - acc: 0.6970
# Epoch 2/100
# 10/10 [==============================] - 25s - loss: 66.1516 - acc: 0.6971
# Epoch 3/100
# 10/10 [==============================] - 25s - loss: 65.3279 - acc: 0.6970
# Epoch 4/100
# 10/10 [==============================] - 25s - loss: 64.5217 - acc: 0.6971
# Epoch 5/100
# 10/10 [==============================] - 25s - loss: 63.7326 - acc: 0.6971
# Epoch 6/100
# 10/10 [==============================] - 25s - loss: 62.9601 - acc: 0.6973
# Epoch 7/100
# 10/10 [==============================] - 25s - loss: 62.2040 - acc: 0.6975
# Epoch 8/100
# 10/10 [==============================] - 25s - loss: 61.4637 - acc: 0.6975
# Epoch 9/100
# 10/10 [==============================] - 25s - loss: 60.7379 - acc: 0.6976
# Epoch 10/100
# 10/10 [==============================] - 25s - loss: 60.0283 - acc: 0.6975
# Epoch 11/100
# 10/10 [==============================] - 25s - loss: 59.3334 - acc: 0.6975
# Epoch 12/100
# 10/10 [==============================] - 25s - loss: 58.6525 - acc: 0.6975
# Epoch 13/100
# 10/10 [==============================] - 25s - loss: 57.9856 - acc: 0.6977
# Epoch 14/100
# 10/10 [==============================] - 25s - loss: 57.3330 - acc: 0.6979
# Epoch 15/100
# 10/10 [==============================] - 25s - loss: 56.6938 - acc: 0.6980
# Epoch 16/100
# 10/10 [==============================] - 25s - loss: 56.0677 - acc: 0.6983
# Epoch 17/100
# 10/10 [==============================] - 25s - loss: 55.4537 - acc: 0.6985
# Epoch 18/100
# 10/10 [==============================] - 25s - loss: 54.8529 - acc: 0.6988
# Epoch 19/100
# 10/10 [==============================] - 25s - loss: 54.2640 - acc: 0.6992
# Epoch 20/100
# 10/10 [==============================] - 25s - loss: 53.6870 - acc: 0.6992
# Epoch 21/100
# 10/10 [==============================] - 25s - loss: 53.1219 - acc: 0.6995
# Epoch 22/100
# 10/10 [==============================] - 25s - loss: 52.5683 - acc: 0.6997
# Epoch 23/100
# 10/10 [==============================] - 25s - loss: 52.0258 - acc: 0.6996
# Epoch 24/100
# 10/10 [==============================] - 25s - loss: 51.4940 - acc: 0.6996
# Epoch 25/100
# 10/10 [==============================] - 25s - loss: 50.9730 - acc: 0.6999
# Epoch 26/100
# 10/10 [==============================] - 25s - loss: 50.4622 - acc: 0.7002
# Epoch 27/100
# 10/10 [==============================] - 26s - loss: 49.9613 - acc: 0.7002
# Epoch 28/100
# 10/10 [==============================] - 25s - loss: 49.4699 - acc: 0.7006
# Epoch 29/100
# Epoch 67/100
# 10/10 [==============================] - 25s - loss: 35.9973 - acc: 0.7073
# Epoch 68/100
# 10/10 [==============================] - 25s - loss: 35.7571 - acc: 0.7075
# Epoch 69/100
# 10/10 [==============================] - 25s - loss: 35.5207 - acc: 0.7074
# Epoch 70/100
# 10/10 [==============================] - 25s - loss: 35.2878 - acc: 0.7075
# Epoch 71/100
# 10/10 [==============================] - 25s - loss: 35.0585 - acc: 0.7073
# Epoch 72/100
# 10/10 [==============================] - 25s - loss: 34.8328 - acc: 0.7072
# Epoch 73/100
# 10/10 [==============================] - 25s - loss: 34.6104 - acc: 0.7072
# Epoch 74/100
# 10/10 [==============================] - 25s - loss: 34.3915 - acc: 0.7074
# Epoch 75/100
# 10/10 [==============================] - 25s - loss: 34.1759 - acc: 0.7075
# Epoch 76/100
# 10/10 [==============================] - 25s - loss: 33.9633 - acc: 0.7076
# Epoch 77/100
# 10/10 [==============================] - 25s - loss: 33.7540 - acc: 0.7081
# Epoch 78/100
# 10/10 [==============================] - 25s - loss: 33.5476 - acc: 0.7081
# Epoch 79/100
# 10/10 [==============================] - 25s - loss: 33.3441 - acc: 0.7080
# Epoch 80/100
# 10/10 [==============================] - 25s - loss: 33.1438 - acc: 0.7080
# Epoch 81/100
# 10/10 [==============================] - 25s - loss: 32.9464 - acc: 0.7082
# Epoch 82/100
# 10/10 [==============================] - 25s - loss: 32.7517 - acc: 0.7085
# Epoch 83/100
# 10/10 [==============================] - 25s - loss: 32.5599 - acc: 0.7083
# Epoch 84/100
# 10/10 [==============================] - 25s - loss: 32.3707 - acc: 0.7084
# Epoch 85/100
# 10/10 [==============================] - 25s - loss: 32.1841 - acc: 0.7087
# Epoch 86/100
# 10/10 [==============================] - 25s - loss: 32.0002 - acc: 0.7088
# Epoch 87/100
# 10/10 [==============================] - 25s - loss: 31.8187 - acc: 0.7089
# Epoch 88/100
# 10/10 [==============================] - 25s - loss: 31.6397 - acc: 0.7089
# Epoch 89/100
# 10/10 [==============================] - 25s - loss: 31.4632 - acc: 0.7090
# Epoch 90/100
# 10/10 [==============================] - 25s - loss: 31.2890 - acc: 0.7090
# Epoch 91/100
# 10/10 [==============================] - 25s - loss: 31.1172 - acc: 0.7091
# Epoch 92/100
# 10/10 [==============================] - 25s - loss: 30.9476 - acc: 0.7093
# Epoch 93/100
# 10/10 [==============================] - 25s - loss: 30.7804 - acc: 0.7093
# Epoch 94/100
# 10/10 [==============================] - 25s - loss: 30.6153 - acc: 0.7095
# Epoch 95/100
# 10/10 [==============================] - 25s - loss: 30.4524 - acc: 0.7094
# Epoch 96/100
# 10/10 [==============================] - 25s - loss: 30.2916 - acc: 0.7094
# Epoch 97/100
# 10/10 [==============================] - 25s - loss: 30.1328 - acc: 0.7094
# Epoch 98/100
# 10/10 [==============================] - 25s - loss: 29.9760 - acc: 0.7096
# Epoch 99/100
# 10/10 [==============================] - 25s - loss: 29.8214 - acc: 0.7098
# Epoch 100/100
# 10/10 [==============================] - 25s - loss: 29.6684 - acc: 0.7096

# %%
a = tl_model.predict(XX_train[0:1, :, :, :])

# %%
a = a.reshape(224,224,2)

# %%
i = np.append(XX_train[0,:,:,0:1], a, axis=2)

# %%
b = Image.fromarray(i, mode='YCbCr').convert('RGB')

# %%
c = img_to_array(b)

# %%
plt.imshow(c)
