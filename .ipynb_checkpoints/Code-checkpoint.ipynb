# %%
import keras
from keras.applications import VGG16
from keras.models import Model
from keras.layers.pooling import MaxPooling2D
from keras.preprocessing.image import ImageDataGenerator, array_to_img, img_to_array, load_img
from keras.models import Sequential
from keras.layers import Convolution2D, MaxPooling2D, UpSampling2D
from keras.layers import Activation, Dropout, Flatten, Dense
from keras.applications.vgg16 import VGG16
import os
import numpy as np
from keras.applications.imagenet_utils import preprocess_input 
from keras.utils import np_utils
import random
import pprint
import cPickle
from scipy.misc import imread, imresize, imsave
from keras.layers.normalization import BatchNormalization
from keras import backend as K
from keras.engine.topology import Merge, merge

# %%
def rgb_to_yuv(inp):
    cnv = np.array([[0.299, 0.587, 0.114], [-0.14713, -0.28886, 0.436], [0.615, -0.51499, -0.10001]])
    return np.dot(inp, cnv.T)

random.seed(0)

X_train = []
Y_train = []

for directory in os.listdir('./data/'):
    for i,image in enumerate(random.sample(os.listdir('./data/' + directory),3)):
        img = load_img('./data/' + directory + '/' + image, target_size=(224,224))  # this is a PIL image
        x = img_to_array(img)
        x_yuv = rgb_to_yuv(x)
        Y_train.append(x_yuv[:,:,1:])
        X_train.append(x_yuv[:,:,:1])
X_train = np.array(X_train)
Y_train = np.array(Y_train)

# %%
def getModel():
    ''' 
        * return: compiled model (keras.engine.training.Model)
    '''
    vgg_model = VGG16( weights='imagenet', include_top=True )
    for i in range(9):
        vgg_model.layers.pop()    
    
    bnl = BatchNormalization() (vgg_model.layers[-1].output)
    cnl = Convolution2D(256, 1, 1, border_mode='same') (bnl)
    usl = UpSampling2D() (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-5].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(128, 3, 3, border_mode='same') (ml)

    usl = UpSampling2D() (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-9].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(64, 3, 3, border_mode='same') (ml)

    usl = UpSampling2D() (cnl)
    bnl = BatchNormalization() (vgg_model.layers[-12].output)
    ml = merge([usl, bnl], mode='sum')
    cnl = Convolution2D(3, 3, 3, border_mode='same') (ml)

    bnl = BatchNormalization() (vgg_model.layers[-14].output)
    ml = merge([cnl, bnl], mode='sum')
    cnl = Convolution2D(3, 3, 3, border_mode='same') (ml)

    cnl = Convolution2D(2, 3, 3, border_mode='same') (cnl)

    tl_model = Model( input=vgg_model.input, output=cnl )
    for i in range(1, 14):
        tl_model.layers[i].trainable = False

    return tl_model

# %%
tl_model = getModel()
pprint.PrettyPrinter(indent=2).pprint(tl_model.get_config())
# # tl_model.summary()

# tl_model.compile(loss="categorical_crossentropy", optimizer="adagrad", metrics=["acc"])
# Out:
# { 'input_layers': [['input_7', 0, 0]],
#   'layers': [ { 'class_name': 'InputLayer',
#                 'config': { 'batch_input_shape': (None, 224, 224, 3),
#                             'input_dtype': 'float32',
#                             'name': 'input_7',
#                             'sparse': False},
#                 'inbound_nodes': [],
#                 'name': 'input_7'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block1_conv1',
#                             'nb_col': 3,
#                             'nb_filter': 64,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['input_7', 0, 0]]],
#                 'name': 'block1_conv1'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block1_conv2',
#                             'nb_col': 3,
#                             'nb_filter': 64,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block1_conv1', 0, 0]]],
#                 'name': 'block1_conv2'},
#               { 'class_name': 'MaxPooling2D',
#                 'config': { 'border_mode': 'valid',
#                             'dim_ordering': 'tf',
#                             'name': 'block1_pool',
#                             'pool_size': (2, 2),
#                             'strides': (2, 2),
#                             'trainable': False},
#                 'inbound_nodes': [[['block1_conv2', 0, 0]]],
#                 'name': 'block1_pool'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block2_conv1',
#                             'nb_col': 3,
#                             'nb_filter': 128,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block1_pool', 0, 0]]],
#                 'name': 'block2_conv1'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block2_conv2',
#                             'nb_col': 3,
#                             'nb_filter': 128,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block2_conv1', 0, 0]]],
#                 'name': 'block2_conv2'},
#               { 'class_name': 'MaxPooling2D',
#                 'config': { 'border_mode': 'valid',
#                             'dim_ordering': 'tf',
#                             'name': 'block2_pool',
#                             'pool_size': (2, 2),
#                             'strides': (2, 2),
#                             'trainable': False},
#                 'inbound_nodes': [[['block2_conv2', 0, 0]]],
#                 'name': 'block2_pool'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block3_conv1',
#                             'nb_col': 3,
#                             'nb_filter': 256,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block2_pool', 0, 0]]],
#                 'name': 'block3_conv1'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block3_conv2',
#                             'nb_col': 3,
#                             'nb_filter': 256,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block3_conv1', 0, 0]]],
#                 'name': 'block3_conv2'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block3_conv3',
#                             'nb_col': 3,
#                             'nb_filter': 256,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block3_conv2', 0, 0]]],
#                 'name': 'block3_conv3'},
#               { 'class_name': 'MaxPooling2D',
#                 'config': { 'border_mode': 'valid',
#                             'dim_ordering': 'tf',
#                             'name': 'block3_pool',
#                             'pool_size': (2, 2),
#                             'strides': (2, 2),
#                             'trainable': False},
#                 'inbound_nodes': [[['block3_conv3', 0, 0]]],
#                 'name': 'block3_pool'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block4_conv1',
#                             'nb_col': 3,
#                             'nb_filter': 512,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block3_pool', 0, 0]]],
#                 'name': 'block4_conv1'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block4_conv2',
#                             'nb_col': 3,
#                             'nb_filter': 512,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block4_conv1', 0, 0]]],
#                 'name': 'block4_conv2'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'relu',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'block4_conv3',
#                             'nb_col': 3,
#                             'nb_filter': 512,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': False},
#                 'inbound_nodes': [[['block4_conv2', 0, 0]]],
#                 'name': 'block4_conv3'},
#               { 'class_name': 'BatchNormalization',
#                 'config': { 'axis': -1,
#                             'beta_regularizer': None,
#                             'epsilon': 0.001,
#                             'gamma_regularizer': None,
#                             'mode': 0,
#                             'momentum': 0.99,
#                             'name': 'batchnormalization_94',
#                             'trainable': True},
#                 'inbound_nodes': [[['block4_conv3', 0, 0]]],
#                 'name': 'batchnormalization_94'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_85',
#                             'nb_col': 1,
#                             'nb_filter': 256,
#                             'nb_row': 1,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['batchnormalization_94', 0, 0]]],
#                 'name': 'convolution2d_85'},
#               { 'class_name': 'UpSampling2D',
#                 'config': { 'name': 'upsampling2d_59',
#                             'size': (2, 2),
#                             'trainable': True},
#                 'inbound_nodes': [[['convolution2d_85', 0, 0]]],
#                 'name': 'upsampling2d_59'},
#               { 'class_name': 'BatchNormalization',
#                 'config': { 'axis': -1,
#                             'beta_regularizer': None,
#                             'epsilon': 0.001,
#                             'gamma_regularizer': None,
#                             'mode': 0,
#                             'momentum': 0.99,
#                             'name': 'batchnormalization_95',
#                             'trainable': True},
#                 'inbound_nodes': [[['block3_conv3', 0, 0]]],
#                 'name': 'batchnormalization_95'},
#               { 'class_name': 'Merge',
#                 'config': { 'arguments': { },
#                             'concat_axis': -1,
#                             'dot_axes': -1,
#                             'mode': 'sum',
#                             'mode_type': 'raw',
#                             'name': 'merge_60',
#                             'output_mask': None,
#                             'output_mask_type': 'raw',
#                             'output_shape': None,
#                             'output_shape_type': 'raw'},
#                 'inbound_nodes': [ [ ['upsampling2d_59', 0, 0],
#                                      ['batchnormalization_95', 0, 0]]],
#                 'name': 'merge_60'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_86',
#                             'nb_col': 3,
#                             'nb_filter': 128,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['merge_60', 0, 0]]],
#                 'name': 'convolution2d_86'},
#               { 'class_name': 'UpSampling2D',
#                 'config': { 'name': 'upsampling2d_60',
#                             'size': (2, 2),
#                             'trainable': True},
#                 'inbound_nodes': [[['convolution2d_86', 0, 0]]],
#                 'name': 'upsampling2d_60'},
#               { 'class_name': 'BatchNormalization',
#                 'config': { 'axis': -1,
#                             'beta_regularizer': None,
#                             'epsilon': 0.001,
#                             'gamma_regularizer': None,
#                             'mode': 0,
#                             'momentum': 0.99,
#                             'name': 'batchnormalization_96',
#                             'trainable': True},
#                 'inbound_nodes': [[['block2_conv2', 0, 0]]],
#                 'name': 'batchnormalization_96'},
#               { 'class_name': 'Merge',
#                 'config': { 'arguments': { },
#                             'concat_axis': -1,
#                             'dot_axes': -1,
#                             'mode': 'sum',
#                             'mode_type': 'raw',
#                             'name': 'merge_61',
#                             'output_mask': None,
#                             'output_mask_type': 'raw',
#                             'output_shape': None,
#                             'output_shape_type': 'raw'},
#                 'inbound_nodes': [ [ ['upsampling2d_60', 0, 0],
#                                      ['batchnormalization_96', 0, 0]]],
#                 'name': 'merge_61'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_87',
#                             'nb_col': 3,
#                             'nb_filter': 64,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['merge_61', 0, 0]]],
#                 'name': 'convolution2d_87'},
#               { 'class_name': 'UpSampling2D',
#                 'config': { 'name': 'upsampling2d_61',
#                             'size': (2, 2),
#                             'trainable': True},
#                 'inbound_nodes': [[['convolution2d_87', 0, 0]]],
#                 'name': 'upsampling2d_61'},
#               { 'class_name': 'BatchNormalization',
#                 'config': { 'axis': -1,
#                             'beta_regularizer': None,
#                             'epsilon': 0.001,
#                             'gamma_regularizer': None,
#                             'mode': 0,
#                             'momentum': 0.99,
#                             'name': 'batchnormalization_97',
#                             'trainable': True},
#                 'inbound_nodes': [[['block1_conv2', 0, 0]]],
#                 'name': 'batchnormalization_97'},
#               { 'class_name': 'Merge',
#                 'config': { 'arguments': { },
#                             'concat_axis': -1,
#                             'dot_axes': -1,
#                             'mode': 'sum',
#                             'mode_type': 'raw',
#                             'name': 'merge_62',
#                             'output_mask': None,
#                             'output_mask_type': 'raw',
#                             'output_shape': None,
#                             'output_shape_type': 'raw'},
#                 'inbound_nodes': [ [ ['upsampling2d_61', 0, 0],
#                                      ['batchnormalization_97', 0, 0]]],
#                 'name': 'merge_62'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_88',
#                             'nb_col': 3,
#                             'nb_filter': 3,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['merge_62', 0, 0]]],
#                 'name': 'convolution2d_88'},
#               { 'class_name': 'BatchNormalization',
#                 'config': { 'axis': -1,
#                             'beta_regularizer': None,
#                             'epsilon': 0.001,
#                             'gamma_regularizer': None,
#                             'mode': 0,
#                             'momentum': 0.99,
#                             'name': 'batchnormalization_98',
#                             'trainable': True},
#                 'inbound_nodes': [[['input_7', 0, 0]]],
#                 'name': 'batchnormalization_98'},
#               { 'class_name': 'Merge',
#                 'config': { 'arguments': { },
#                             'concat_axis': -1,
#                             'dot_axes': -1,
#                             'mode': 'sum',
#                             'mode_type': 'raw',
#                             'name': 'merge_63',
#                             'output_mask': None,
#                             'output_mask_type': 'raw',
#                             'output_shape': None,
#                             'output_shape_type': 'raw'},
#                 'inbound_nodes': [ [ ['convolution2d_88', 0, 0],
#                                      ['batchnormalization_98', 0, 0]]],
#                 'name': 'merge_63'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_89',
#                             'nb_col': 3,
#                             'nb_filter': 3,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['merge_63', 0, 0]]],
#                 'name': 'convolution2d_89'},
#               { 'class_name': 'Convolution2D',
#                 'config': { 'W_constraint': None,
#                             'W_regularizer': None,
#                             'activation': 'linear',
#                             'activity_regularizer': None,
#                             'b_constraint': None,
#                             'b_regularizer': None,
#                             'bias': True,
#                             'border_mode': 'same',
#                             'dim_ordering': 'tf',
#                             'init': 'glorot_uniform',
#                             'name': 'convolution2d_90',
#                             'nb_col': 3,
#                             'nb_filter': 2,
#                             'nb_row': 3,
#                             'subsample': (1, 1),
#                             'trainable': True},
#                 'inbound_nodes': [[['convolution2d_89', 0, 0]]],
#                 'name': 'convolution2d_90'}],
#   'name': 'model_23',
#   'output_layers': [['convolution2d_90', 0, 0]]}

# %%
# # history = tl_model.fit_generator(train_datagen.flow(X_train,Y_train,batch_size=88), samples_per_epoch=88, nb_epoch=50, validation_data=(X_valid,Y_valid), verbose=1)

# history = tl_model.fit(X_train,Y_train,batch_size=22, nb_epoch=20, validation_data=(X_valid,Y_valid), verbose=1, shuffle=True)

# tl_model.save(filepath='./output/urban_2_images')
# cPickle.dump( history.history, open( "urbnan_2_images.p", "wb" ) )
